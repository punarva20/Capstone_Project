# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df_booking = pd.read_csv('/Users/neuefische/project_analysis_booking_com/data/booking_hotel.csv', encoding='windows-1252')

# %%
df_booking.head(20)
# Out:
#                                            Hotel Name  \
# 0                    Krabi La Playa Resort - SHA Plus
# 1                         KC Beach Club & Pool Villas
# 2                        Rawai VIP Villas & Kids Park
# 3                     FuramaXclusive Sathorn, Bangkok
# 4                   Bo Phut Resort and Spa - SHA Plus
# 5                Abloom Exclusive Serviced Apartments
# 6      Bandara Suites Silom, Bangkok - SHA Extra Plus
# 7                             Bhukitta Boutique Hotel
# 8                                     Hotel Verdigris
# 9                             Combo Beach Hotel Samui
# 10        Spacious apartment with Ocean view in Panwa
# 11    Explorar Koh Samui - Adults Only Resort and Spa
# 12                Waterfront Suites Phuket by Centara
# 13  Art Mai Gallery Nimman Hotel Chiang Mai - SHA ...
# 14   The Leaf Oceanside by Katathani - SHA Extra Plus
# 15  Twin Lotus Resort and Spa - SHA Plus - Adult O...
# ...

# %%
df_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3465 entries, 0 to 3464
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Hotel Name                                 3465 non-null   object
#  1   Location                                   3465 non-null   object
#  2   Rating                                     3365 non-null   object
#  3   Review Score                               3359 non-null   object
#  4   Number of                                  3359 non-null   object
#  5   Room    Score                              2709 non-null   float64
#  6   Room Type                                  3465 non-null   object
#  7   Bed Type                                   3449 non-null   object
#  8   Room Price (in BDT or any other currency)  3465 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 243.8+ KB

# %%
df_booking['Room Price (in BDT or any other currency)'] =df_booking['Room Price (in BDT or any other currency)'].str.strip().str.replace('"', '')

# %%
df_booking['Room Price (in BDT or any other currency)']
# Out:
# 0         146,026
# 1         215,304
# 2         435,384
# 3         146,240
# 4         621,072
#           ...
# 3460      209,678
# 3461      118,712
# 3462    1,177,140
# 3463      227,402
# 3464      648,803
# Name: Room Price (in BDT or any other currency), Length: 3465, dtype: object

# %%
df = pd.to_numeric(df_booking['Room Price (in BDT or any other currency)'].astype(float))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.to_numeric(df_booking['Room Price (in BDT or any other currency)'].astype(float))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...
